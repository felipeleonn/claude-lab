# %%
from api_setup import client, model, add_user_message, add_assistant_message, chat

# %%
messages = []
# add_user_message(messages, "Hola")

# answer = chat(messages)

# add_assistant_message(messages, answer)

add_user_message(messages, "write another sentence")
answer = chat(messages, 1.0)

# messages
answer
# Out:
# 'The cat stretched lazily across the sunny windowsill, purring contentedly.'

# %%
message = []
add_user_message(messages, "Write a python function that checks a string for duplicate characters")

answer = chat(messages, 0.2,system="You are a Python engineer who writes very concise code")
answer
# Out:
# '```python\ndef has_duplicates(s: str) -> bool:\n    return len(s) != len(set(s))\n```'

# %%
messages = []

add_user_message(messages, "Write a 1 sentence description of fake database")

with client.messages.stream(
    model=model,
    max_tokens=1000,
    messages=messages
) as stream:
    for text in stream.text_stream:
        print(text, end="")
# Out:
# # Fake Database
#
# A fake database is a mock or simulated data storage system used in testing and development that mimics the behavior of a real database without actually persisting data to disk or requiring complex setup.
